# %% [markdown]
# # Taller 2
#
# ### Gustavo Alonso Gomez Morales

# %%
import sys
import os

notebook_dir = os.path.abspath('.')
parent_dir = os.path.dirname(notebook_dir)
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

from util import *

import cv2
from matplotlib import pyplot as plt
import numpy as np
from IPython.display import Image

# %% [markdown]
# ## Negativo de una imagen

# %% [markdown]
# Este punto consiste en tomar la imagen "bacteria.jpeg" y convertirla a su negativo. El negativo de una imagen se obtiene restando a cada pixel el valor 255, pero aquí está la novedad: vamos a realizar el negativo no en escala de grises, sino en cada canal de color por separado. Es decir, si un pixel tiene el valor (r, g, b), el negativo de ese pixel será (255-r, 255-g, 255-b).

# %% [markdown]
# ### Imagen original

# %%
Image("res/activity-1/bacteria.jpeg")

# %% [markdown]
# ### Imagen deseada

# %%
Image("res/activity-1/negativo.png")

# %%
image = image_read("res/activity-1/bacteria.jpeg")

image[:,:,0] = 255 - image[:,:,0]
image[:,:,1] = 255 - image[:,:,1]
image[:,:,2] = 255 - image[:,:,2]

image_show(image, "Negative")

# %% [markdown]
# ## Encoger el histograma

# %% [markdown]
# Disminuya el histograma de la imagen "teatro.jpg" en un 50%. El resultado esperado son cuatro imágenes: la imagen original, el histograma original, la imagen modificada y el histograma modificado.

# %%
Image("res/activity-2/teatro.jpg")

# %%
image = image_read("res/activity-2/teatro.jpg")
modified_image = linear_transformation(image, 0.5, 0, "color")

plot_image_and_histogram(image, "Original", "Original Image", "Original Histogram")
plot_image_and_histogram(modified_image, "Modified", "Modified Image", "Modified Histogram")

# %% [markdown]
# ## Resta de imágenes

# %% [markdown]
# Reste la imagen "Dos.png" a la imagen "Uno.png" y muestre el resultado (Uno - Dos). Si lo desea puede usar un treshold para que el resultado sea más claro, este último es opcional.

# %% [markdown]
# ### Resultado esperado (no tiene que ser exacto)

# %%
Image("res/activity-3/resultado.png")

# %%
image_one = image_read("res/activity-3/Uno.png")
image_two = image_read("res/activity-3/Dos.png")

result_image = cv2.subtract(image_one, image_two)
image_show(result_image, "Result")
